# %%
v=open("abc.txt","w")
v.close()

# %%
file=open("abc.txt","r")
file.close()

# %%
file=open("/content/drive/MyDrive/Colab Notebooks/abc.txt","r")
cont=file.read()
print(cont)
file.close()
# Out:
# My name is Gurmannat

# %%
file=open("/content/drive/MyDrive/Colab Notebooks/abc.txt", "r")
cont=file.write()
print(cont)
file.close()
# Out:
# My name is Gurmannat

# %%
path="/content/drive/MyDrive/Colab Notebooks/abc.txt"
file1=open(path+"abc.txt","w")
file1.write("I am 2nd line,")
file1.close()

# %%
file=open("/content/drive/MyDrive/Colab Notebooks/abc.txtnewfile.txt","r")
cont=file.read()
print(cont)
file.close()
# Out:
# I am 2nd line,

# %%
file2=open("/content/drive/MyDrive/Colab Notebooks/abc.txtnewfile.txt","w+")
file2.write("Akash,23 \n Mahima,45 \n Nitin, 90 \n Suhesh,89")
file2.seek(0)
content=file2.read()
print(content)
file2.close()
# Out:
# Akash,23
#  Mahima,45
#  Nitin, 90
#  Suhesh,89

# %%
file2=open(path,"r")
content=file2.read()
print(content)
file2.close()
# Out:
# My name is Gurmannat
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77

# %%
file2=open("/content/drive/MyDrive/Colab Notebooks/abc.txtnewfile.txt","r")
content=file2.read()
print(content)
file2.close()
# Out:
# Akash,23
#  Mahima,45
#  Nitin, 90
#  Suhesh,89

# %%
with open(path,"r") as file3:
  cont=file3.read()
  print(cont)
# Out:
# My name is Gurmannat
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77

# %%
### Modes
# a
# a+
# x
# ab
# wb
# wb+
# r+
# rb
# rb+

# %%
with open("/content/drive/MyDrive/Colab Notebooks/abc.txt","a") as file3:
  file3.write("\nNaina, 99\nManish, 88\nAmit, 77")

# %%
with open("/content/drive/MyDrive/Colab Notebooks/abc.txt","r") as file3:
  cont=file3.readlines()
  for i in cont:
    print(i.strip())
# Out:
# My name is Gurmannat
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77
# Naina, 99
# Manish, 88
# Amit, 77

# %%
with open("marks.txt", "r") as file:
  for line in file:
    name , marks = line.strip().split(":")

    print (name.strip())
    print (marks.strip())
    print()
# Out:
# Rohan
# 25
#
# Rahul
# 67
#
# Ram
# 44
#
# Karan
# 93
#
# Bhangu
# 88

# %%
#problem statement

# %%
file = open("marks.txt","w+")
file.write("Rohan : 25 \nRahul : 67 \nRam : 44 \nKaran : 93 \nBhangu : 88")
file.close()

file = open("marks.txt","r")
cont = file.read()
print(cont)
file.close()
# Out:
# Rohan : 25
# Rahul : 67
# Ram : 44
# Karan : 93
# Bhangu : 88

# %%
file = open("marks.txt", "r")

pass_count = 0
fail_count = 0

for i in file:
  name, marks = i.split(":")
  marks = int(marks.strip())
  name = name.strip()

  if marks > 45:
    print(name, " has passed the exam with", marks,"marks")
    pass_count +=1
  else:
    print(name,"has failed the exam with", marks,"marks")
file.close()

print("\nPass students:", pass_count)
print("fail students", fail_count)
# Out:
# Rohan has failed the exam with 25 marks
# Rahul  has passed the exam with 67 marks
# Ram has failed the exam with 44 marks
# Karan  has passed the exam with 93 marks
# Bhangu  has passed the exam with 88 marks
#
# Pass students: 3
# fail students 0
